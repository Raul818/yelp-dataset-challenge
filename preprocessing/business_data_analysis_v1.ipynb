# %%
from pandas.io.json import json_normalize
import pandas as pd

# %%
pd.__version__
# Out:
# '0.19.0'

# %%
df_business = pd.read_json('../yelp_academic_dataset_business.json', lines=True)

# %%
len(df_business)
# Out:
# 85901

# %%
df_business_restaurants = df_business[df_business['categories'].apply(lambda x: 'Restaurants' in x)].reset_index(drop=True)
df_business_restaurants
# Out:
#                                               attributes  \
# 0      {'Takes Reservations': False, 'Good for Kids':...
# 1      {'Takes Reservations': False, 'Caters': True, ...
# 2      {'Takes Reservations': False, 'Caters': False,...
# 3      {'Takes Reservations': False, 'Outdoor Seating...
# 4      {'Takes Reservations': False, 'Caters': False,...
# 5      {'Takes Reservations': False, 'Caters': False,...
# 6      {'Takes Reservations': False, 'Good for Kids':...
# 7      {'Music': {'dj': False, 'background_music': Fa...
# 8                                                     {}
# 9      {'Takes Reservations': False, 'Good for Kids':...
# 10     {'Has TV': True, 'Outdoor Seating': False, 'Ta...
# 11     {'Takes Reservations': False, 'Good for Kids':...
# 12     {'Takes Reservations': True, 'Good for Kids': ...
# 13     {'Takes Reservations': False, 'Good for Kids':...
# 14     {'Takes Reservations': False, 'Outdoor Seating...
# ...

# %%
df_business_restaurants.drop(['latitude','longitude','neighborhoods','type','full_address'], axis=1, inplace=True)
df_business_restaurants
# Out:
#                                               attributes  \
# 0      {'Takes Reservations': False, 'Good for Kids':...
# 1      {'Takes Reservations': False, 'Caters': True, ...
# 2      {'Takes Reservations': False, 'Caters': False,...
# 3      {'Takes Reservations': False, 'Outdoor Seating...
# 4      {'Takes Reservations': False, 'Caters': False,...
# 5      {'Takes Reservations': False, 'Caters': False,...
# 6      {'Takes Reservations': False, 'Good for Kids':...
# 7      {'Music': {'dj': False, 'background_music': Fa...
# 8                                                     {}
# 9      {'Takes Reservations': False, 'Good for Kids':...
# 10     {'Has TV': True, 'Outdoor Seating': False, 'Ta...
# 11     {'Takes Reservations': False, 'Good for Kids':...
# 12     {'Takes Reservations': True, 'Good for Kids': ...
# 13     {'Takes Reservations': False, 'Good for Kids':...
# 14     {'Takes Reservations': False, 'Outdoor Seating...
# ...

# %%
# Out:
#       Accepts Credit Cards   Alcohol  \
# 0                     True      none
# 1                     True  full_bar
# 2                     True  full_bar
# 3                     True      none
# 4                     True  full_bar
# 5                    False      none
# 6                     True      none
# 7                     True  full_bar
# 8                      NaN       NaN
# 9                     True      none
# 10                    True      none
# 11                    True      none
# 12                    True  full_bar
# 13                    True      none
# 14                    True       NaN
# 15                    True      none
# 16                    True      none
# 17                    True  full_bar
# 18                    True  full_bar
# 19                    True      none
# 20                     NaN       NaN
# 21                    True  full_bar
# 22                    True  full_bar
# 23                    True      none
# ...

# %%
df_business_cat.rename(columns={0:'Category_0',1:'Category_1',2:'Category_2',3:'Category_3',4:'Category_4',
                       5:'Category_5',6:'Category_6',7:'Category_7',8:'Category_8',9:'Category_9'}
                       ,inplace=True)
df_business_catsplit = pd.concat([df_business.drop(['categories'], axis=1), df_business_cat], axis = 1)
cat_columns = df_business_catsplit[df_business_catsplit.columns[pd.Series(df_business_catsplit.columns).str.startswith('Category_')]]
df_business_restaurants = df_business_catsplit[(cat_columns == 'Restaurants').any(axis=1)].dropna(how='all')
#del df_business_restaurants['latitude','longitude','name']
df_business_restaurants.drop(['latitude','longitude','name','neighborhoods','type','full_address'], axis=1, inplace=True)
df_business_restaurants_attributes = df_business_restaurants['attributes'].apply(pd.Series)
df_business_restaurants_attributes.columns
# Out:
# Index(['Accepts Credit Cards', 'Accepts Insurance', 'Ages Allowed', 'Alcohol',
#        'Ambience', 'Attire', 'BYOB', 'BYOB/Corkage', 'By Appointment Only',
#        'Caters', 'Coat Check', 'Corkage', 'Delivery', 'Dietary Restrictions',
#        'Dogs Allowed', 'Drive-Thru', 'Good For', 'Good For Dancing',
#        'Good For Groups', 'Good for Kids', 'Happy Hour', 'Has TV', 'Music',
#        'Noise Level', 'Open 24 Hours', 'Order at Counter', 'Outdoor Seating',
#        'Parking', 'Price Range', 'Smoking', 'Take-out', 'Takes Reservations',
#        'Waiter Service', 'Wheelchair Accessible', 'Wi-Fi'],
#       dtype='object')

# %%
df_business_restaurants.groupby(['city'])['business_id'].count()
# Out:
# city
# Ahwatukee               4
# Allentown               1
# Anjou                   6
# Anthem                 37
# Apache Junction        58
# Arlington               1
# Asheville               1
# Aspinwall               4
# Avondale              135
# Baie-D'urfe             1
# Balerno                 1
# Beaconsfield            5
# Bellevue               13
# Bellvue                 2
# Belmont                35
# Bietigheim              3
# Black Canyon City       1
# Blainville              2
# Blawnox                 1
# Bloomfield              1
# Bocholt                 1
# Bois-Des-Filion         1
# Boisbriand              7
# Boulder City           11
# Braddock                1
# Brentwood               3
# Bridgeville             6
# Brookline               1
# Brossard               55
# Bruchsal                1
#                      ...
# Tega Cay               10
# Tempe                 816
# Terrebonne              6
# Tolleson               28
# ...

# %%
df_business_restaurants[df_business_restaurants['open'] == True]
# Out:
#                                               attributes  \
# 0      {'Price Range': 1, 'Caters': False, 'Good for ...
# 3      {'Caters': True, 'Good For Groups': True, 'Att...
# 5      {'Caters': False, 'Good For Groups': True, 'At...
# 12     {'Price Range': 1, 'Good for Kids': True, 'Del...
# 17     {'Caters': False, 'Good For Groups': True, 'At...
# 18     {'Caters': False, 'Good For Groups': False, 'A...
# 19     {'Price Range': 1, 'Good for Kids': True, 'Del...
# 22                                                    {}
# 24     {'Price Range': 1, 'Caters': False, 'Good for ...
# 26     {'Good for Kids': True, 'Delivery': True, 'Alc...
# 28     {'Price Range': 1, 'Caters': False, 'Good for ...
# 30     {'Price Range': 2, 'Caters': True, 'Good for K...
# 31     {'Price Range': 2, 'Caters': False, 'Good for ...
# 33     {'Price Range': 1, 'Good For Groups': True, 'D...
# 34     {'Price Range': 1, 'Caters': False, 'Good for ...
# ...

# %%
df_business_restaurants.sort_values(by = ['review_count'])['review_count']
# Out:
# 35877       3
# 28699       3
# 65300       3
# 40796       3
# 83541       3
# 80726       3
# 84879       3
# 79463       3
# 51282       3
# 79460       3
# 84884       3
# 51312       3
# 83538       3
# 51198       3
# 13359       3
# 65225       3
# 28702       3
# 32306       3
# 65197       3
# 51456       3
# 65160       3
# 20519       3
# 17443       3
# 51521       3
# 14938       3
# 40696       3
# 40682       3
# 65226       3
# 40830       3
# 40846       3
#          ...
# 20431    1788
# 72851    1814
# 77808    1818
# 20202    1842
# 55554    1844
# 47131    1856
# 73698    1922
# 20555    2089
# 20191    2120
# 9095     2142
# 20279    2148
# 20065    2266
# 50407    2362
# 57276    2441
# 46318    2622
# 20067    2643
# 20798    2857
# 50579    3086
# 20204    3134
# 20058    3225
# 20239    3305
# 20349    3546
# 41238    3577
# 63825    3767
# 36507    3781
# 62785    4620
# 27816    4687
# 50493    4967
# 60454    5216
# 20187    6200
# ...

# %%
df_business_restaurants.columns
# Out:
# Index(['attributes', 'business_id', 'city', 'full_address', 'hours',
#        'latitude', 'longitude', 'name', 'neighborhoods', 'open',
#        'review_count', 'stars', 'state', 'type', 'Category_0', 'Category_1',
#        'Category_2', 'Category_3', 'Category_4', 'Category_5', 'Category_6',
#        'Category_7', 'Category_8', 'Category_9'],
#       dtype='object')

# %%
df_business_restaurants['stars']

df_business_restaurants['stars_int'] = df_business_restaurants['stars'].apply(round)

# %%
df_business_restaurants.groupby(['stars_int'])['business_id'].count()
# Out:
# stars_int
# 1      103
# 2     4390
# 3     4594
# 4    17102
# 5      540
# Name: business_id, dtype: int64

# %%
num_cities = len(df_business_restaurants['city'].unique())

df_business_cities_of_stars = df_business_restaurants.groupby(['stars_int','city'])['business_id'].count()

# df_business_restaurants.groupby(['stars_int'])['business_id'].count()
df_business_cities_of_stars.iloc[['5'], :]

# df_business_restaurants.groupby(['stars_int'])['city'].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-d4fab3ce5d31> in <module>()
#       4
#       5 # df_business_restaurants.groupby(['stars_int'])['business_id'].count()
# ----> 6 df_business_cities_of_stars.iloc[['5'], :]
#       7
#       8 # df_business_restaurants.groupby(['stars_int'])['city'].count()
#
# /Users/greeshmaswaminathan/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1307
#    1308         if type(key) is tuple:
# -> 1309             return self._getitem_tuple(key)
#    1310         else:
#    1311             return self._getitem_axis(key, axis=0)
#
# /Users/greeshmaswaminathan/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1557     def _getitem_tuple(self, tup):
#    1558
# -> 1559         self._has_valid_tuple(tup)
#    1560         try:
# ...

# %%
df = pd.DataFrame(df_business_cities_of_stars)
print (df.head())
print (df.columns)
# Out:
#                           business_id
# stars_int city
# 1         Avondale                  2
#           Buckeye                   1
#           Casa Grande               1
#           Castle Shannon            1
#           Chandler                  3
# Index(['business_id'], dtype='object')

# %%
df[df['stars_int']==1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/greeshmaswaminathan/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2103             try:
# -> 2104                 return self._engine.get_loc(key)
#    2105             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4160)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4024)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13161)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13115)()
#
# KeyError: 'stars_int'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Out:
# 26729
